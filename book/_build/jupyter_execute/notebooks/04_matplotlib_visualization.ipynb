# %% [markdown]
# # Lab 04 — Visualization with Matplotlib

# %%
import pandas as pd
from courseutils.plotting import line
df = pd.read_csv('../data/air_quality_sample.csv', parse_dates=['date'])
ax = line(df['date'], df['pm25'], title='PM2.5 over Time', xlabel='Date', ylabel='PM2.5')
ax.figure
