# %% [markdown]
# # Lab 01 — Python Basics
# This lab refreshes Python essentials for scientific computing.

# %%
a = 3
b = 4
print('Sum:', a + b)

# %%
def fib(n):
    x, y = 0, 1
    out = []
    for _ in range(n):
        out.append(x)
        x, y = y, x + y
    out
    print(out)

fib(10)
