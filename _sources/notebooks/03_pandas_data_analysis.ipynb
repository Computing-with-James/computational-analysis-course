# %% [markdown]
# # Lab 03 — Pandas Data Analysis
# Load, inspect, and summarize a small dataset.

# %%
import pandas as pd
df = pd.read_csv('../data/air_quality_sample.csv', parse_dates=['date'])
df.head()

# %%
df.describe()

# %%
daily = df.set_index('date').resample('1D').mean()
daily
